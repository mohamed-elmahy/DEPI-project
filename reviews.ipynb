# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("/content/reviews.csv")
data.head(10)
# Out:
#    review_id  customer_id  product_id  rating  comment   review_date
# 0          1         2819         247       4      Bad  INVALID_DATE
# 1          2          633         281       2      Bad   Dec-21-2022
# 2          3         4465         226       3     Good    2024-09-29
# 3          4         4969         214       4      NaN   Jul-24-2024
# 4          5         3481         500       1  Average    11-19-2023
# 5          6         2095         406       3  Average    06/03/2023
# 6          7         4834         134       4      Bad    06-08-2022
# 7          8         2694         434       2      Bad    04/05/2023
# 8          9          847          42       3      Bad    2024-11-24
# 9         10         4417         280       3     Good   Jul-11-2022

# %%
data.isna().sum()
# Out:
# review_id         0
# customer_id       0
# product_id        0
# rating            0
# comment        1653
# review_date       0
# dtype: int64

# %%
data.shape
# Out:
# (10000, 6)

# %%
data['review_date'] = data['review_date'].str.replace(r'/', '-', regex=True)
data.head(10)
# Out:
#    review_id  customer_id  product_id  rating  comment   review_date
# 0          1         2819         247       4      Bad  INVALID_DATE
# 1          2          633         281       2      Bad   Dec-21-2022
# 2          3         4465         226       3     Good    2024-09-29
# 3          4         4969         214       4      NaN   Jul-24-2024
# 4          5         3481         500       1  Average    11-19-2023
# 5          6         2095         406       3  Average    06-03-2023
# 6          7         4834         134       4      Bad    06-08-2022
# 7          8         2694         434       2      Bad    04-05-2023
# 8          9          847          42       3      Bad    2024-11-24
# 9         10         4417         280       3     Good   Jul-11-2022

# %%
data['comment'] = data['comment'].fillna("No comment")
data.head(10)
# Out:
#    review_id  customer_id  product_id  rating     comment   review_date
# 0          1         2819         247       4         Bad  INVALID_DATE
# 1          2          633         281       2         Bad   Dec-21-2022
# 2          3         4465         226       3        Good    2024-09-29
# 3          4         4969         214       4  No comment   Jul-24-2024
# 4          5         3481         500       1     Average    11-19-2023
# 5          6         2095         406       3     Average    06-03-2023
# 6          7         4834         134       4         Bad    06-08-2022
# 7          8         2694         434       2         Bad    04-05-2023
# 8          9          847          42       3         Bad    2024-11-24
# 9         10         4417         280       3        Good   Jul-11-2022

# %%
col_name = "review_date"

# حذف العمود نهائيًا من الداتا
data.drop(columns=[col_name], inplace=True)

# تأكيد إن العمود اتشال
data.head()
# Out:
#    review_id  customer_id  product_id  rating     comment
# 0          1         2819         247       4         Bad
# 1          2          633         281       2         Bad
# 2          3         4465         226       3        Good
# 3          4         4969         214       4  No comment
# 4          5         3481         500       1     Average

# %%
data.isna().sum()
# Out:
# review_id      0
# customer_id    0
# product_id     0
# rating         0
# comment        0
# dtype: int64
